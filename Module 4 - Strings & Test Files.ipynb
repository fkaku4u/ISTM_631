# %%
def reverse(text):
    a = ""
    for i in range(1, len(text) + 1):
        a += text[len(text) - i]
    return a

print(reverse("Good Morning!")) # prints: !gninroM dooG
# Out:
# !gninroM dooG

# %%
#for loop that adds the characters from myString to reversedString in reverse order

myString = input(str("Enter your string: "))

reversedString = ""
for x in myString:
    reversedString = x + reversedString
    
reversedString
# Out:
# Enter your string: Hello
# 'olleH'

# %%
# You are given a string that was encoded by a Caesar cipher with an unknown distance value. 
# The text can contain any of the printable ASCII characters. 
# Suggest an algorithm for cracking this code.

string = input("Enter a message: ")
n = int(input("Enter the distance value: "))
output = ""
for i in string:
    output += chr(ord(i)+n)
print(output)
# Out:
# Enter a message: Hello
# Enter the distance value: 4
# Lipps

# %%
#The Caesar cipher basically shifts each letter of plaintext by a fixed number. For example, if the key 2 is used, the word Sourpuss would be encoded Uqwrtrwuu
#The text can contain only the printable ASCII characters (32-126, for our purposes). Implement an algorithm for cracking this code.
#I need to decrypt this: "T! x$r&'}r&z! %21j!'1~zxy&1"r%%1TZedBEAB?"

def decoded(s):
    for i in range(1,95):
        string = ""
        for char in s:
            if(ord(char) + i > 126):
                charc = (ord(char) + i) - 95 mk    m,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
                string =  string + chr(charc)
            else:
               charc = ord(char) + i
               string =  string + chr(charc) 

        print(string)
# Out:
#   File "<ipython-input-11-848fd807fe1c>", line 10
# ...

# %%
#The Caesar cipher is a simple form of a “substitution cipher” where you replace each letter of the alphabet with another letter by shifting the whole alphabet a certain number of letters (wrapping around to the beginning once you reach the end). For example, this would be your key and code if you shift each letter by three spaces:

#Plain:     ABCDEFGHIJKLMNOPQRSTUVWXYZ
#Cipher:   XYZABCDEFGHIJKLMNOPQRSTUVW

#So, when you write your message, the letter A gets replaced with X, B gets replaced with Y and so on. For example, the word “HELLO” reads:

#Plain:    HELLO
#Cipher:  EBIIL    
    
    
    
    def decoded(s):
        for i in range(1,95):
            string = ""
            for char in s:
                    if(ord(char) + i > 126):
                        charc = (ord(char) + i) - 95
                        string =  string + chr(charc)
                    else:
                       charc = ord(char) + i
                       string =  string + chr(charc) 

                    print(string)
                    
decoded("T! x$r&'}r&z! %21j!'1~zxy&1\"r%%1TZedBEAB?")
# Out:
# U
# U"
# U"!
# U"!y
# U"!y%
# U"!y%s
# U"!y%s'
# U"!y%s'(
# U"!y%s'(~
# U"!y%s'(~s
# U"!y%s'(~s'
# U"!y%s'(~s'{
# U"!y%s'(~s'{"
# U"!y%s'(~s'{"!
# U"!y%s'(~s'{"!&
# U"!y%s'(~s'{"!&3
# U"!y%s'(~s'{"!&32
# U"!y%s'(~s'{"!&32k
# U"!y%s'(~s'{"!&32k"
# U"!y%s'(~s'{"!&32k"(
# U"!y%s'(~s'{"!&32k"(2
# U"!y%s'(~s'{"!&32k"(2
# U"!y%s'(~s'{"!&32k"(2 {
# U"!y%s'(~s'{"!&32k"(2 {y
# U"!y%s'(~s'{"!&32k"(2 {yz
# U"!y%s'(~s'{"!&32k"(2 {yz'
# U"!y%s'(~s'{"!&32k"(2 {yz'2
# U"!y%s'(~s'{"!&32k"(2 {yz'2#
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[f
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[fe
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[feC
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[feCF
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[feCFB
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[feCFBC
# U"!y%s'(~s'{"!&32k"(2 {yz'2#s&&2U[feCFBC@
# V
# V#
# V#"
# ...

# %%
plainText = input("text to encrypt: ") 
#distance = int(input("distance: ")) 
distance = 3
code = "" 
for ch in plainText:    
    ordValue = ord(ch)  
    cipherValue = ordValue + distance   
    if cipherValue > ord('z'):      
        cipherValue = ord('a') + distance - (ord('z') - ordValue + 1)
    code = code + chr(cipherValue)
print(code)

# %%
plainText = input("text to encrypt: ") 
#distance = int(input("distance: ")) 
distance = 3
code = "" 
for ch in plainText:    
    ordValue = ord(ch)  
    cipherValue = ordValue + distance   
    if cipherValue > ord('z'):      
        cipherValue = ord('a') + distance - (ord('z') - ordValue + 1)
    code = code + chr(cipherValue)
print(code)
# Out:
# text to encrypt: wow
# zrz

# %%
count = 0
inputFile = open("myfile.txt", 'r')

for line in inputFile:

    wordlist = line.split()

    for word in wordlist:

        if len(word) == 4:

            count += 1

print("There are", count, "lines.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-dbceb492ce37> in <module>
#       1 count = 0
# ----> 2 inputFile = open("myfile.txt", 'r')
#       3
#       4 for line in inputFile:
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'myfile.txt'

# %%
file = input("Enter file name:")
f = open(file, 'r')
# To read all lines of the file
nums = f.readlines()
# To remove all blank lines of the file
for i in nums:
    if i == '\n':
        nums.remove(i)
# To convert numbers to int data type
for i in range(0, len(nums)):
    nums[i] = int(nums[i])

# To calculate the sum
total = sum(nums)
# To calculate the average
average = total / len(nums)
# Printing average
print('The average of the numbers is', average)

# %%
#Prompting the user to input the text to be encrypted
text = input("Please enter any text: ")

#Prompting the user to input the distance
d = int(input("Please enter the distance : "))

encryptedCode = ""

#Logic for encrypting
for character in text:
#ord returns int value for unicode
oV = ord(character)  
c = oV + d
if c > ord('z'):   
c = ord('a') + d - (ord('z') - oV + 1)
encryptedCode = encryptedCode + chr(c)

#Printing the encrypted text
print('Encrypted text: '+encryptedCode)

# %%
string = input("Enter encrypted text: ")
n = int(input("Enter the distance value: "))
print()
output = ""
for i in string:
    output += chr(ord(i)-n)
    n += 1
print("Plain text:",output)

# %%
# encrypt.py

# prompt user to enter the input file name
inputFile = input("Enter the input file name: ")

# prompt user to enter the output file name
outputFile = input("Enter the output file name: ")

# prompt user to enter the distance value
distance = int(input("Enter the distance value: "))

# input file path
fInput = open("/Users/swapnil/PycharmProjects/EncryptAndDecrypt /encrypt.txt", "r")

# output file path
fOutput = open("/Users/swapnil/PycharmProjects/EncryptAndDecrypt /a.txt", "w")

# iterate through the file data
for inLine in fInput:
    for ch in inLine:
        orderValue = ord(ch)
        cipherValue = orderValue + distance
        if cipherValue > 127:
            cipherValue = distance - (127 - orderValue + 1)
        fOutput.write(chr(cipherValue))

fInput.close
fOutput.close
